# %% [markdown]
# # 🎯 **Step 0: Import Library**
# ---

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 🎯 **Step 1: Load Dataset**
# ---

# %% [markdown]
# ## ✨ 1.1 - Dataset URL 1

# %% [markdown]
# Dataset URL 1 ini berasal dari paper

# %%
path = '/content/drive/MyDrive/SKILL ACADEMY/FINAL PROJECT/Dataset/URL/URL.xlsx'

df_url_first = pd.read_excel(path)

df_url_first.head()
# Out:
#   Category                                               Data
# 0     spam  logtelstra2021.ddnsking.com/0dfa1b53b835500696...
# 1     spam  dvsber.ru/modules/mod_ariimageslidersa/KRENK3N...
# 2     spam  kimsinc564.000webhostapp.com/notification.php?...
# 3     spam                                     benjim.com/all
# 4     spam                    www.m.micesrunescape.com-we.ru/

# %% [markdown]
# ## ✨ 1.2 - Dataset URL 2

# %%
path = '/content/drive/MyDrive/SKILL ACADEMY/FINAL PROJECT/Dataset/URL/PhiUSIIL_Phishing_URL_Dataset.csv'

df_url_second = pd.read_csv(path)

df_url_second.head()
# Out:
#      FILENAME                                 URL  URLLength  \
# 0  521848.txt    https://www.southbankmosaics.com         31
# 1   31372.txt            https://www.uni-mainz.de         23
# 2  597387.txt      https://www.voicefmradio.co.uk         29
# 3  554095.txt         https://www.sfnmjournal.com         26
# 4  151578.txt  https://www.rewildingargentina.org         33
#
#                        Domain  DomainLength  IsDomainIP  TLD  \
# 0    www.southbankmosaics.com            24           0  com
# 1            www.uni-mainz.de            16           0   de
# 2      www.voicefmradio.co.uk            22           0   uk
# 3         www.sfnmjournal.com            19           0  com
# 4  www.rewildingargentina.org            26           0  org
#
#    URLSimilarityIndex  CharContinuationRate  TLDLegitimateProb  ...  Pay  \
# 0               100.0              1.000000           0.522907  ...    0
# 1               100.0              0.666667           0.032650  ...    0
# ...

# %% [markdown]
# # 🎯 **Step 2: Preprocessing Dataset**
# ---

# %% [markdown]
# ## ✨ 2.1 - Dataset URL 1

# %%
df_url_first['Category'].replace({'spam': 'phishing', 'ham': 'non-phishing'}, inplace=True)
df_url_first.rename(columns={'Data': 'URL'}, inplace=True)

df_url_first.head()
# Out:
#    Category                                                URL
# 0  phishing  logtelstra2021.ddnsking.com/0dfa1b53b835500696...
# 1  phishing  dvsber.ru/modules/mod_ariimageslidersa/KRENK3N...
# 2  phishing  kimsinc564.000webhostapp.com/notification.php?...
# 3  phishing                                     benjim.com/all
# 4  phishing                    www.m.micesrunescape.com-we.ru/

# %% [markdown]
# ## ✨ 2.1 - Dataset URL 2

# %%
df_url_second.rename(columns={'label': 'Category'}, inplace=True)

# %%
df_url_second['Category'].replace({1: 'phishing', 0: 'non-phishing'}, inplace=True)

df_url_second.head()
# Out:
#      FILENAME                                 URL  URLLength  \
# 0  521848.txt    https://www.southbankmosaics.com         31
# 1   31372.txt            https://www.uni-mainz.de         23
# 2  597387.txt      https://www.voicefmradio.co.uk         29
# 3  554095.txt         https://www.sfnmjournal.com         26
# 4  151578.txt  https://www.rewildingargentina.org         33
#
#                        Domain  DomainLength  IsDomainIP  TLD  \
# 0    www.southbankmosaics.com            24           0  com
# 1            www.uni-mainz.de            16           0   de
# 2      www.voicefmradio.co.uk            22           0   uk
# 3         www.sfnmjournal.com            19           0  com
# 4  www.rewildingargentina.org            26           0  org
#
#    URLSimilarityIndex  CharContinuationRate  TLDLegitimateProb  ...  Pay  \
# 0               100.0              1.000000           0.522907  ...    0
# 1               100.0              0.666667           0.032650  ...    0
# ...

# %%
df_url_second = df_url_second[['URL', 'Category']]

df_url_second.head()
# Out:
#                                   URL  Category
# 0    https://www.southbankmosaics.com  phishing
# 1            https://www.uni-mainz.de  phishing
# 2      https://www.voicefmradio.co.uk  phishing
# 3         https://www.sfnmjournal.com  phishing
# 4  https://www.rewildingargentina.org  phishing

# %% [markdown]
# # 🎯 **Step 3: Save the Dataset**
#
# ---

# %% [markdown]
# ## ✨ 3.1 - Dataset URL 1

# %%
file_path = '/content/drive/MyDrive/SKILL ACADEMY/FINAL PROJECT/Dataset/URL/first_dataset_url.csv'

df_url_first.to_csv(file_path, index=False)

# %% [markdown]
# ## ✨ 3.2 - Dataset URL 2

# %%
file_path = '/content/drive/MyDrive/SKILL ACADEMY/FINAL PROJECT/Dataset/URL/second_dataset_url.csv'

df_url_second.to_csv(file_path, index=False)
